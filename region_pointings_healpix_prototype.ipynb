# %% [markdown]
# Get a list of coordinates covering the region 'bbox' below in circles with radius 'rad'

# %% [markdown]
# ## Healpix

# %%
from astropy import units

bbox = dict(ramin=21 * units.degree,
            ramax=23 * units.degree,
            decmin=32 * units.degree,
            decmax=34 * units.degree)

rad = 12 *units.arcmin

# %%
# get the closest smaller size of healpix elements

from moc import utils
level = utils.size_to_level(rad, truncate=True)

from moc import core
dsize = core.HEALPIX_LEVELS[level]

print("Healpix' level {:d} corresponds to a size '{}'".format(level,dsize))
# Out:
# Healpix' level 8 corresponds to a size '13.74 arcmin'

# %%
# create a grid of (fake) coordinates, to then create a MOC table from it
step_size = dsize.to('deg').value/2**0.5

import numpy as np
ra_vec = np.arange(bbox['ramin'].value, bbox['ramax'].value, step_size)
dec_vec = np.arange(bbox['decmin'].value, bbox['decmax'].value, step_size)

# %%
import itertools
grid = list(itertools.product(ra_vec,dec_vec))

# %%
from astropy.coordinates import SkyCoord
coords = SkyCoord(grid,unit='deg')

# %% [markdown]
# ## A MOC catalog (with hierarchical coverage)

# %%
from mocpy import MOC
moc = MOC.from_coo_list(coords, level)

# %%
tmpfile = 'moc.json'
moc.write(tmpfile, format='json')

import json
with open(tmpfile, 'r') as fp:
    dmoc = json.load(fp)
    
import os
os.remove(tmpfile)

# %%
from healpy import pixelfunc

def moc_to_pointings(moc_dict):
    coords_dict = {}
    for k,v in moc_dict.items():
        level = int(k)
        nside = 2**level
        coords = []
        for ipix in v:
            c = pixelfunc.pix2ang(nside, ipix, nest=True, lonlat=True)
            coords.append(c)
        coords = list(zip(*coords))
        size = core.HEALPIX_LEVELS[level]
        coords_dict[level] = dict(radius=size, ra=coords[0], dec=coords[1])
    return coords_dict

# %% [markdown]
# ### Plot

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="194ca423-b218-4704-a659-ab0b559edfda">Loading BokehJS ...</span>
#     </div>

# %%
coords_moc = moc_to_pointings(dmoc)

colors = ['green','yellow','blue','red']
levels = list(map(int,coords_moc.keys()))

fig = figure()
for i in range(len(levels)):
    lvl = levels[i]
    clr = colors[i]

    x = coords_moc[lvl]['ra']
    y = coords_moc[lvl]['dec']
    r = coords_moc[lvl]['radius'].to('deg').value

    fig.circle(x, y, radius=r, fill_alpha=0.25, color=clr)
    
show(fig)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b8e75e2f-b5b7-4249-86b5-8f66d249f4b4"></div>
# </div>

# %% [markdown]
# ## A list of fixed-order Healpix elements

# %%
# Read the coordinates representing (center) each element of our interest

from healpy import pixelfunc

# defined earlier:
# -ra_vec
# -dec_vec
# -radius
# -level

nside = 2**level

pix_to_visit = set()
for ra,dec in grid:
    ipix = pixelfunc.ang2pix(nside, ra, dec, nest=True, lonlat=True)
    pix_to_visit.add(ipix)

coords_to_visit = []
for ipix in pix_to_visit:
    c = pixelfunc.pix2ang(nside, ipix, nest=True, lonlat=True)
    coords_to_visit.append(c)

    ## We don't need the neighbours, but if that was the case:
    #
    #nipixs = pixelfunc.get_all_neighbours(nside, c[0], c[1], nest=True, lonlat=True)
    #cns = []
    #for nipix in nipixs:
    #    cns.append(pixelfunc.pix2ang(nside, nipix, nest=True, lonlat=True))
    #coords_to_visit.extend(cns)

# %%
x_hp,y_hp = list(zip(*coords_to_visit))
r_hp = core.HEALPIX_LEVELS[level].to('deg').value
r_og = rad.to('deg').value

print('radii:', r_hp, r_og)
# Out:
# radii: 0.229 0.2

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

output_notebook()

fig = figure()
fig.circle(x_hp,y_hp,radius=r_og, fill_alpha=0.1, color='red')
fig.circle(x_hp,y_hp,radius=r_hp, fill_alpha=0.1)
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="312d33bc-e52f-4b10-9cfd-d2b0f1584abb">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ff27b50e-1497-4f59-b94e-c4773f2c57a3"></div>
# </div>

# %% [markdown]
# ## Create the list of pointings

# %%
import pandas

df = pandas.DataFrame({'ra':x_hp, 'dec':y_hp, 'radius':r_hp*60})
df
# Out:
#           dec         ra  radius
# 0   31.914005  21.093750   13.74
# 1   31.914005  21.445312   13.74
# 2   32.089951  21.621094   13.74
# 3   32.089951  21.269531   13.74
# 4   32.266237  21.445312   13.74
# 5   32.442866  22.675781   13.74
# 6   32.089951  20.917969   13.74
# 7   32.266237  21.093750   13.74
# 8   32.442866  21.269531   13.74
# 9   32.442866  20.917969   13.74
# 10  32.619842  21.093750   13.74
# 11  32.266237  21.796875   13.74
# 12  32.442866  21.972656   13.74
# 13  32.442866  21.621094   13.74
# 14  32.619842  21.796875   13.74
# 15  32.619842  22.148438   13.74
# 16  32.797168  22.324219   13.74
# 17  32.797168  21.972656   13.74
# 18  32.974849  22.148438   13.74
# 19  32.619842  21.445312   13.74
# 20  32.797168  21.621094   13.74
# 21  32.797168  21.269531   13.74
# 22  32.974849  21.445312   13.74
# 23  32.974849  21.796875   13.74
# 24  33.152888  21.972656   13.74
# 25  33.152888  21.621094   13.74
# 26  33.331289  21.796875   13.74
# 27  32.797168  20.917969   13.74
# 28  31.914005  21.796875   13.74
# 29  32.974849  21.093750   13.74
# ..        ...        ...     ...
# 54  33.510056  22.324219   13.74
# 55  33.510056  21.972656   13.74
# 56  33.689193  22.148438   13.74
# 57  33.689193  22.500000   13.74
# 58  33.510056  22.675781   13.74
# 59  33.868705  22.324219   13.74
# 60  34.048594  22.500000   13.74
# 61  33.868705  22.675781   13.74
# 62  33.331289  22.851562   13.74
# 63  33.689193  22.851562   13.74
# 64  33.868705  23.027344   13.74
# 65  34.048594  22.851562   13.74
# 66  33.689193  21.796875   13.74
# 67  33.868705  21.972656   13.74
# 68  33.868705  21.621094   13.74
# 69  34.048594  21.796875   13.74
# 70  34.048594  22.148438   13.74
# 71  31.914005  22.500000   13.74
# 72  31.914005  22.851562   13.74
# 73  32.442866  23.027344   13.74
# 74  34.048594  21.445312   13.74
# 75  32.619842  22.851562   13.74
# 76  32.797168  22.675781   13.74
# 77  32.974849  22.851562   13.74
# 78  32.089951  23.027344   13.74
# 79  32.797168  23.027344   13.74
# 80  33.152888  23.027344   13.74
# 81  32.089951  22.675781   13.74
# 82  32.266237  22.851562   13.74
# 83  33.510056  23.027344   13.74
#
# [84 rows x 3 columns]

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
def sds_cmdline(df_row):
    cmdline = 'docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky'
    ra = df_row['ra']
    dec = df_row['dec']
    radius = df_row['radius']
    lbl = '{:d}_{:d}_{:d}'.format(int(df_row['index']), int(ra), int(dec))
    cmdline += ' --ra {:.5f} --dec {:.5f} --radius {:.3f} --label {!s}'
    cmdline = cmdline.format(ra, dec, radius, lbl)
#     print(cmdline)
    return cmdline
    
cmdlines = df.reset_index().apply(sds_cmdline, axis=1)

# %%
cmdlines.to_csv('swift_deepsky_pointings_list.txt', header=False, index=False)

# %%
# %cat swift_deepsky_pointings_list.txt
# Out:
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 33.15289 --radius 13.740 --label 0_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 32.97485 --radius 13.740 --label 1_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 33.15289 --radius 13.740 --label 2_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 33.68919 --radius 13.740 --label 3_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 33.33129 --radius 13.740 --label 4_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 33.51006 --radius 13.740 --label 5_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 32.61984 --radius 13.740 --label 6_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 31.91400 --radius 13.740 --label 7_21_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 32.44287 --radius 13.740 --label 8_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 32.79717 --radius 13.740 --label 9_20_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 33.51006 --radius 13.740 --label 10_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 32.61984 --radius 13.740 --label 11_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 32.61984 --radius 13.740 --label 12_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 31.91400 --radius 13.740 --label 13_21_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 33.15289 --radius 13.740 --label 14_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 33.86870 --radius 13.740 --label 15_23_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 33.33129 --radius 13.740 --label 16_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 33.86870 --radius 13.740 --label 17_20_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 32.79717 --radius 13.740 --label 18_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 33.51006 --radius 13.740 --label 19_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 32.44287 --radius 13.740 --label 20_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 33.86870 --radius 13.740 --label 21_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 32.79717 --radius 13.740 --label 22_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 32.08995 --radius 13.740 --label 23_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 32.26624 --radius 13.740 --label 24_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 32.26624 --radius 13.740 --label 25_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 33.68919 --radius 13.740 --label 26_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 31.91400 --radius 13.740 --label 27_22_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 32.08995 --radius 13.740 --label 28_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 32.44287 --radius 13.740 --label 29_23_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 33.15289 --radius 13.740 --label 30_20_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 32.44287 --radius 13.740 --label 31_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 32.26624 --radius 13.740 --label 32_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 33.51006 --radius 13.740 --label 33_23_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 33.68919 --radius 13.740 --label 34_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 32.08995 --radius 13.740 --label 35_20_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 33.68919 --radius 13.740 --label 36_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 32.61984 --radius 13.740 --label 37_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 33.68919 --radius 13.740 --label 38_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 32.08995 --radius 13.740 --label 39_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 32.08995 --radius 13.740 --label 40_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 34.04859 --radius 13.740 --label 41_22_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 31.91400 --radius 13.740 --label 42_22_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 33.15289 --radius 13.740 --label 43_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 34.04859 --radius 13.740 --label 44_21_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 34.04859 --radius 13.740 --label 45_21_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.79688 --dec 32.97485 --radius 13.740 --label 46_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 31.91400 --radius 13.740 --label 47_22_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 32.79717 --radius 13.740 --label 48_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 33.33129 --radius 13.740 --label 49_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 33.51006 --radius 13.740 --label 50_20_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 34.04859 --radius 13.740 --label 51_21_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 32.61984 --radius 13.740 --label 52_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 33.68919 --radius 13.740 --label 53_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 32.26624 --radius 13.740 --label 54_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 32.79717 --radius 13.740 --label 55_23_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 32.97485 --radius 13.740 --label 56_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 32.97485 --radius 13.740 --label 57_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 33.33129 --radius 13.740 --label 58_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 32.44287 --radius 13.740 --label 59_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 34.04859 --radius 13.740 --label 60_22_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 32.08995 --radius 13.740 --label 61_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 33.86870 --radius 13.740 --label 62_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.67578 --dec 32.79717 --radius 13.740 --label 63_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.85156 --dec 33.33129 --radius 13.740 --label 64_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 33.51006 --radius 13.740 --label 65_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 34.04859 --radius 13.740 --label 66_22_34
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 32.08995 --radius 13.740 --label 67_23_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 32.79717 --radius 13.740 --label 68_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 32.26624 --radius 13.740 --label 69_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 33.86870 --radius 13.740 --label 70_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 31.91400 --radius 13.740 --label 71_21_31
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.09375 --dec 32.97485 --radius 13.740 --label 72_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 32.26624 --radius 13.740 --label 73_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 33.51006 --radius 13.740 --label 74_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.50000 --dec 33.33129 --radius 13.740 --label 75_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 20.91797 --dec 32.44287 --radius 13.740 --label 76_20_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.44531 --dec 32.97485 --radius 13.740 --label 77_21_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.26953 --dec 33.86870 --radius 13.740 --label 78_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.32422 --dec 33.86870 --radius 13.740 --label 79_22_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 22.14844 --dec 32.61984 --radius 13.740 --label 80_22_32
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 23.02734 --dec 33.15289 --radius 13.740 --label 81_23_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.97266 --dec 33.15289 --radius 13.740 --label 82_21_33
# docker run --rm -v /scratch/work:/work chbrandt/swift_deepsky --ra 21.62109 --dec 32.44287 --radius 13.740 --label 83_21_32
